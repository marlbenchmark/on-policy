# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the win rate training data
df_orig = pd.read_csv('win_rate_training.csv')

# %%
nan_mask = df_orig.isna()

# Restrict to 1e7 steps
df = df_orig[df_orig['Step'] <= 1e7].copy()

df["Experiment 1 - incre_win_rate"] = df["Experiment 0 (Original Version) - incre_win_rate"]

# Save to CSV
df.to_csv('win_rate_training_cleaned.csv', index=False)
